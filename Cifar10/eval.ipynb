# %%
from solver import Solver, plot_csv
from data_utils import CIFAR10Data
from resnet import ResNet18

# %%
cifar10 = CIFAR10Data()
data = cifar10.get_noisy_data()

model = ResNet18(classes=10, input_shape=(32, 32, 3), weight_decay=1e-4)
model.load_weight("20201104_072322_noise0.1/best_val_acc.hdf5")

solver = Solver(model, data)
solver.test()

# %%
plot_csv("/home/kitamura/work/DeepLearning/Cifar10/csv/20201104_072322_noise0.1.csv")
